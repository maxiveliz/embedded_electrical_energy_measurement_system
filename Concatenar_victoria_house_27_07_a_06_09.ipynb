# %%
import pandas as pd
import numpy as np
from datetime import datetime
import glob
import cv2

# %% [markdown]
# ---
# * Caloventor
# * Heladera 1
# * Heladera 2
# * Laptop
# * Lavarropas
# * Lavavajillas
# * Pava eléctrica
# * Televisor
# * Heladera 1
# * Heladera 2
# * Laptop
# * Lavarropas
# * Lavavajillas
# * Pava eléctrica
# * Televisor
#
#
#
# ---

# %% [markdown]
# P_Aggregate

# %%
import os
os.chdir('/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/P')

# %%
for f in os.listdir():
  texto, extension= os.path.splitext(f)
  #print(texto)
  print(texto.split('-'))
  d1,m1,a1,d2,m2,a2=texto.split('-')
  #print(d1)
  nuevo_archivo=f"{m1}-{d1}-{a1}-{m2}-{d2}-{a2}{extension}"
  #print(nuevo_archivo)
  os.rename(f, nuevo_archivo)
# Out:
# ['P[kW] agregada']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-e2cd8b6e4d5f> in <cell line: 0>()
#       3   #print(texto)
#       4   print(texto.split('-'))
# ----> 5   d1,m1,a1,d2,m2,a2=texto.split('-')
#       6   #print(d1)
#       7   nuevo_archivo=f"{m1}-{d1}-{a1}-{m2}-{d2}-{a2}{extension}"
#
# ValueError: not enough values to unpack (expected 6, got 1)

# %%
my_list=[]

# %%
file_list= glob.glob('/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/P/*.xlsx')
print(file_list)
# Out:
# ['/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/P/27-07-20 - 28-07-20.xlsx', '/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/P/28-07-20 - 29-07-20.xlsx', '/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/P/29-07-20 - 30-07-20.xlsx', '/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/P/30-07-20 - 31-07-20.xlsx', '/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/P/31-07-20 - 01-08-20.xlsx', '/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/
# ...

# %%
path= '/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/P/*.xlsx'

# %%
for i in sorted(glob.glob(path)):
  print(i)
# Out:
# /content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/P/01-08-20 - 02-08-20.xlsx
# /content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/P/01-09-20 - 02-09-20.xlsx
# /content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/P/02-08-20 - 03-08-20.xlsx
# /content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/P/02-09-20 - 03-09-20.xlsx
# /content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/P/03-08-20 - 04-08-20.xlsx
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
for i in sorted(glob.glob(path)):
  df=pd.read_excel(i)
  my_list.append(pd.read_excel(i))
# Out:
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...

# %%
df_todos_P=pd.concat(my_list,join="inner", ignore_index=True)

# %%
df_todos_P
# Out:
#       Circuito 1 Circuito 2 Circuito 3  Total                 Date
# 0              0          0          0      0  2020-08-01 00:01:00
# 1              0          0          0      0  2020-08-01 00:02:00
# 2              0          0          0      0  2020-08-01 00:03:00
# 3              0          0          0      0  2020-08-01 00:04:00
# 4              0          0          0      0  2020-08-01 00:05:00
# ...          ...        ...        ...    ...                  ...
# 60475      0.064          0          0  0.064  2020-08-31 23:56:00
# 60476      0.063          0          0  0.063  2020-08-31 23:57:00
# 60477      0.064          0          0  0.064  2020-08-31 23:58:00
# 60478      0.064          0          0  0.064  2020-08-31 23:59:00
# 60479      0.064          0          0  0.064  2020-09-01 00:00:00
#
# [60480 rows x 5 columns]

# %%
df_todos_P.describe()
# Out:
#         Circuito 1  Circuito 2  Circuito 3  Total                 Date
# count        60480       60480       60480  60480                60480
# unique        1401           2           2   1401                60480
# top              0           0           0      0  2020-08-31 23:44:00
# freq         18450       58412       58412  18450                    1

# %%
import matplotlib.pyplot as plt

# %%
df_todos_P['Date'][0:1440]
# Out:
# 0       2020-08-01 00:01:00
# 1       2020-08-01 00:02:00
# 2       2020-08-01 00:03:00
# 3       2020-08-01 00:04:00
# 4       2020-08-01 00:05:00
#                ...
# 1435    2020-08-01 23:56:00
# 1436    2020-08-01 23:57:00
# 1437    2020-08-01 23:58:00
# 1438    2020-08-01 23:59:00
# 1439    2020-08-02 00:00:00
# Name: Date, Length: 1440, dtype: object

# %%
#df_todos_P=df_todos.drop(['Circuito 2','Circuito 3', 'Total'], axis=1)
df_todos_P['Circuito 1'].replace(
    to_replace=['---'],
    value=0,
    inplace=True
)

#plt.figure(figsize=(10,6))
#fig3=df_todos_P.plot("Date","Circuito 1")



plt.plot(df_todos_P.index[0:1440], df_todos_P['Circuito 1'][0:1440])
plt.title('Potencia activa señal agregada')
plt.xlabel('samples')
plt.ylabel('P [kW]')
plt.grid()

plt.savefig('/content/image/P_agregada_cuel_house_24')

plt.show()

# %% [markdown]
# Q_Aggregate

# %%
import os
os.chdir('/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/Q')

# %%
for f in os.listdir():
  texto, extension= os.path.splitext(f)
  #print(texto)
  print(texto.split('-'))
  d1,m1,a1,d2,m2,a2=texto.split('-')
  #print(d1)
  nuevo_archivo=f"{m1}-{d1}-{a1}-{m2}-{d2}-{a2}{extension}"
  #print(nuevo_archivo)
  os.rename(f, nuevo_archivo)
# Out:
# ['07', '27', '20 ', '07', ' 28', '20']
# ['07', '28', '20 ', '07', ' 29', '20']
# ['07', '29', '20 ', '07', ' 30', '20']
# ['07', '30', '20 ', '07', ' 31', '20']
# ['07', '31', '20 ', '08', ' 01', '20']
# ['08', '01', '20 ', '08', ' 02', '20']
# ['08', '02', '20 ', '08', ' 03', '20']
# ['08', '03', '20 ', '08', ' 04', '20']
# ['08', '04', '20 ', '08', ' 05', '20']
# ['08', '05', '20 ', '08', ' 06', '20']
# ['08', '06', '20 ', '08', ' 07', '20']
# ['08', '07', '20 ', '08', ' 08', '20']
# ['08', '08', '20 ', '08', ' 09', '20']
# ['08', '09', '20 ', '08', ' 10', '20']
# ['08', '10', '20 ', '08', ' 11', '20']
# ['08', '11', '20 ', '08', ' 12', '20']
# ['08', '12', '20 ', '08', ' 13', '20']
# ['08', '13', '20 ', '08', ' 14', '20']
# ['08', '14', '20 ', '08', ' 15', '20']
# ['08', '15', '20 ', '08', ' 16', '20']
# ['08', '16', '20 ', '08', ' 17', '20']
# ['08', '17', '20 ', '08', ' 18', '20']
# ['08', '18', '20 ', '08', ' 19', '20']
# ['08', '19', '20 ', '08', ' 20', '20']
# ...

# %%
my_list_Q=[]
file_list_Q= glob.glob('/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/Q/*.xlsx')
#print(file_list)
path_Q= '/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/Q/*.xlsx'
for i in sorted(glob.glob(path_Q)):
  print(i)
# Out:
# /content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/Q/01-08-20 - 02-08-20.xlsx
# /content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/Q/01-09-20 - 02-09-20.xlsx
# /content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/Q/02-08-20 - 03-08-20.xlsx
# /content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/Q/02-09-20 - 03-09-20.xlsx
# /content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/Q/03-08-20 - 04-08-20.xlsx
# ...

# %%
for i in sorted(glob.glob(path_Q)):
  df_Q=pd.read_excel(i)
  my_list_Q.append(pd.read_excel(i))
  df_todos_Q=pd.concat(my_list_Q,join="inner", ignore_index=True)
  df_todos_Q
# Out:
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...

# %%
df_todos_Q.describe()
# Out:
#         Circuito 1  Circuito 2  Circuito 3  Total                 Date
# count        60480       60480       60480  60480                60480
# unique         586           2           2    586                60480
# top              0           0           0      0  2020-08-31 23:44:00
# freq         49103       58412       58412  49103                    1

# %%
df_todos_Q
# Out:
#       Circuito 1 Circuito 2 Circuito 3 Total                 Date
# 0              0          0          0     0  2020-08-01 00:01:00
# 1              0          0          0     0  2020-08-01 00:02:00
# 2              0          0          0     0  2020-08-01 00:03:00
# 3              0          0          0     0  2020-08-01 00:04:00
# 4              0          0          0     0  2020-08-01 00:05:00
# ...          ...        ...        ...   ...                  ...
# 60475          0          0          0     0  2020-08-31 23:56:00
# 60476          0          0          0     0  2020-08-31 23:57:00
# 60477          0          0          0     0  2020-08-31 23:58:00
# 60478          0          0          0     0  2020-08-31 23:59:00
# 60479          0          0          0     0  2020-09-01 00:00:00
#
# [60480 rows x 5 columns]

# %%
df_todos_Q['Circuito 1'].replace(
    to_replace=['---'],
    value=0,
    inplace=True
)
#fig4=df_todos_Q.plot("Date","Circuito 1")

plt.plot(df_todos_Q.index, df_todos_Q['Circuito 1'])

plt.title('Potencia reactiva señal agregada')
plt.xlabel('samples')
plt.ylabel('Q [VAr]')
plt.grid()

plt.savefig('/content/imageQ_agregada_cuel_house.png')

# %% [markdown]
# V_Aggregate

# %%
import os
os.chdir('/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/V')

# %%
for f in os.listdir():
  texto, extension= os.path.splitext(f)
  #print(texto)
  print(texto.split('-'))
  d1,m1,a1,d2,m2,a2=texto.split('-')
  #print(d1)
  nuevo_archivo=f"{m1}-{d1}-{a1}-{m2}-{d2}-{a2}{extension}"
  #print(nuevo_archivo)
  os.rename(f, nuevo_archivo)
# Out:
# ['07', '27', '20 ', '07', ' 28', '20']
# ['07', '28', '20 ', '07', ' 29', '20']
# ['07', '29', '20 ', '07', ' 30', '20']
# ['07', '30', '20 ', '07', ' 31', '20']
# ['07', '31', '20 ', '08', ' 01', '20']
# ['08', '01', '20 ', '08', ' 02', '20']
# ['08', '02', '20 ', '08', ' 03', '20']
# ['08', '03', '20 ', '08', ' 04', '20']
# ['08', '04', '20 ', '08', ' 05', '20']
# ['08', '05', '20 ', '08', ' 06', '20']
# ['08', '06', '20 ', '08', ' 07', '20']
# ['08', '07', '20 ', '08', ' 08', '20']
# ['08', '08', '20 ', '08', ' 09', '20']
# ['08', '09', '20 ', '08', ' 10', '20']
# ['08', '10', '20 ', '08', ' 11', '20']
# ['08', '11', '20 ', '08', ' 12', '20']
# ['08', '12', '20 ', '08', ' 13', '20']
# ['08', '13', '20 ', '08', ' 14', '20']
# ['08', '14', '20 ', '08', ' 15', '20']
# ['08', '15', '20 ', '08', ' 16', '20']
# ['08', '16', '20 ', '08', ' 17', '20']
# ['08', '17', '20 ', '08', ' 18', '20']
# ['08', '18', '20 ', '08', ' 19', '20']
# ['08', '19', '20 ', '08', ' 20', '20']
# ...

# %%
my_list_V=[]
file_list_V= glob.glob('/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/V/*.xlsx')
#print(file_list)
path_V= '/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/V/*.xlsx'
for i in sorted(glob.glob(path_V)):
  print(i)
# Out:
# /content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/V/01-08-20 - 02-08-20.xlsx
# /content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/V/01-09-20 - 02-09-20.xlsx
# /content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/V/02-08-20 - 03-08-20.xlsx
# /content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/V/02-09-20 - 03-09-20.xlsx
# /content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/V/03-08-20 - 04-08-20.xlsx
# ...

# %%
for i in sorted(glob.glob(path_V)):
  df_V=pd.read_excel(i)
  my_list_V.append(pd.read_excel(i))
  df_todos_V=pd.concat(my_list_V,join="inner", ignore_index=True)
  df_todos_V
# Out:
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...

# %%
df_todos_V['Circuito 1'].replace(
    to_replace=['---'],
    value=0,
    inplace=True
)
fig6=df_todos_V.plot("Date","Circuito 1")
# Out:
# <ipython-input-58-671f625f8009>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_todos_V['Circuito 1'].replace(
# <ipython-input-58-671f625f8009>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_todos_V['Circuito 1'].replace(

# %%
plt.plot(df_todos_V.index, np.abs( df_todos_V['Circuito 1']))

plt.title('Voltaje [V]')
plt.xlabel('samples')
plt.ylabel('V[V]')
plt.grid()

plt.savefig('/content/image/volt')

# %% [markdown]
# I

# %%
import os
os.chdir('/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/I')

# %%
for f in os.listdir():
  texto, extension= os.path.splitext(f)
  #print(texto)
  print(texto.split('-'))
  d1,m1,a1,d2,m2,a2=texto.split('-')
  #print(d1)
  nuevo_archivo=f"{m1}-{d1}-{a1}-{m2}-{d2}-{a2}{extension}"
  #print(nuevo_archivo)
  os.rename(f, nuevo_archivo)

# %%
my_list_I=[]
file_list_I= glob.glob('/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/I/*.xlsx')
#print(file_list)
path_I= '/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/I/*.xlsx'
for i in sorted(glob.glob(path_I)):
  print(i)

# %%
for i in sorted(glob.glob(path_I)):
  df_I=pd.read_excel(i)
  my_list_I.append(pd.read_excel(i))
  df_todos_I=pd.concat(my_list_I,join="inner", ignore_index=True)
  df_todos_I

# %%
df_todos_I['Circuito 1'].replace(
    to_replace=['---'],
    value=0,
    inplace=True
)



#fig7=df_todos_I.plot("Date","Circuito 1")

plt.plot(df_todos_I.index, df_todos_I['Circuito 1'])

plt.title('Corriente señal agregada')
plt.xlabel('samples')
plt.ylabel('I [A]')
plt.grid()

plt.savefig('/content/imagen/I_agregada_cuel_house')

# %% [markdown]
# THD

# %%
import os
os.chdir('/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/%THD')

# %%
for f in os.listdir():
  texto, extension= os.path.splitext(f)
  #print(texto)
  print(texto.split('-'))
  d1,m1,a1,d2,m2,a2=texto.split('-')
  #print(d1)
  nuevo_archivo=f"{m1}-{d1}-{a1}-{m2}-{d2}-{a2}{extension}"
  #print(nuevo_archivo)
  os.rename(f, nuevo_archivo)

# %%
my_list_THD=[]
file_list_THD= glob.glob('/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/%THD/*.xlsx')
#print(file_list)
path_THD= '/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/%THD/*.xlsx'
for i in sorted(glob.glob(path_THD)):
  print(i)

# %%
for i in sorted(glob.glob(path_THD)):
  df_THD=pd.read_excel(i)
  my_list_THD.append(pd.read_excel(i))
  df_todos_THD=pd.concat(my_list_THD,join="inner", ignore_index=True)
  df_todos_THD

# %%
df_todos_THD['Circuito 1'].replace(
    to_replace=['---'],
    value=0,
    inplace=True
)

#fig10=df_todos_THD.plot("Date","Circuito 1")


plt.plot(df_todos_THD.index, df_todos_THD['Circuito 1'])

plt.title('THD% señal agregada')
plt.xlabel('samples')
plt.ylabel('THD%')
plt.grid()

plt.savefig('/content/imagen/THD_agregada_cuel_house')

# %% [markdown]
# 3er_arm

# %%
import os
os.chdir('/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/3er_arm')

# %%
for f in os.listdir():
  texto, extension= os.path.splitext(f)
  #print(texto)
  print(texto.split('-'))
  d1,m1,a1,d2,m2,a2=texto.split('-')
  #print(d1)
  nuevo_archivo=f"{m1}-{d1}-{a1}-{m2}-{d2}-{a2}{extension}"
  #print(nuevo_archivo)
  os.rename(f, nuevo_archivo)

# %%
my_list_3=[]
file_list_3= glob.glob('/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/3er_arm/*.xlsx')
#print(file_list)
path_3= '/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/3er_arm/*.xlsx'
for i in sorted(glob.glob(path_3)):
  print(i)

# %%
for i in sorted(glob.glob(path_3)):
  df_3=pd.read_excel(i)
  my_list_3.append(pd.read_excel(i))
  df_todos_3=pd.concat(my_list_3,join="inner", ignore_index=True)
  df_todos_3

# %%
df_todos_3['Circuito 1'].replace(
    to_replace=['---'],
    value=0,
    inplace=True
)
#fig12=df_todos_3.plot("Date","Circuito 1")


plt.plot(df_todos_3.index, df_todos_3['Circuito 1'])

plt.title('3th armónico señal agregada')
plt.xlabel('samples')
plt.ylabel('Amplitud [A]')
plt.grid()

plt.savefig('/content/imagen/3_arm_agregada_cuel_house')

# %% [markdown]
# 5to_arm

# %%
import os
os.chdir('/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/5to_arm')

# %%
for f in os.listdir():
  texto, extension= os.path.splitext(f)
  #print(texto)
  print(texto.split('-'))
  d1,m1,a1,d2,m2,a2=texto.split('-')
  #print(d1)
  nuevo_archivo=f"{m1}-{d1}-{a1}-{m2}-{d2}-{a2}{extension}"
  #print(nuevo_archivo)
  os.rename(f, nuevo_archivo)

# %%
my_list_5=[]
file_list_5= glob.glob('/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/5to_arm/*.xlsx')
#print(file_list)
path_5= '/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/5to_arm/*.xlsx'
for i in sorted(glob.glob(path_5)):
  print(i)

# %%
for i in sorted(glob.glob(path_5)):
  df_5=pd.read_excel(i)
  my_list_5.append(pd.read_excel(i))
  df_todos_5=pd.concat(my_list_5,join="inner", ignore_index=True)
  df_todos_5

# %%
df_todos_5['Circuito 1'].replace(
    to_replace=['---'],
    value=0,
    inplace=True
)
#fig13=df_todos_5.plot("Date","Circuito 1")

plt.plot(df_todos_5.index, df_todos_5['Circuito 1'])

plt.title('5th armónico señal agregada')
plt.xlabel('samples')
plt.ylabel('Amplitud [A]')
plt.grid()

plt.savefig('/content/imagen/5_arm_agregada_cuel_house')

# %% [markdown]
# 7mo_arm

# %%
import os
os.chdir('/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/7mo_arm')

# %%
for f in os.listdir():
  texto, extension= os.path.splitext(f)
  #print(texto)
  print(texto.split('-'))
  d1,m1,a1,d2,m2,a2=texto.split('-')
  #print(d1)
  nuevo_archivo=f"{m1}-{d1}-{a1}-{m2}-{d2}-{a2}{extension}"
  #print(nuevo_archivo)
  os.rename(f, nuevo_archivo)

# %%
my_list_7=[]
file_list_7= glob.glob('/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/7mo_arm/*.xlsx')
#print(file_list)
path_7= '/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/7mo_arm/*.xlsx'
for i in sorted(glob.glob(path_7)):
  print(i)

# %%
for i in sorted(glob.glob(path_7)):
  df_7=pd.read_excel(i)
  my_list_7.append(pd.read_excel(i))
  df_todos_7=pd.concat(my_list_7,join="inner", ignore_index=True)
  df_todos_7

# %%
df_todos_7['Circuito 1'].replace(
    to_replace=['---'],
    value=0,
    inplace=True
)
#fig15=df_todos_7.plot("Date","Circuito 1")

plt.plot(df_todos_7.index, df_todos_7['Circuito 1'])

plt.title('7th armónico señal agregada')
plt.xlabel('samples')
plt.ylabel('Amplitud [A]')
plt.grid()

plt.savefig('/content/imagen/7_arm_agregada_cuel_house')

# %% [markdown]
# 9no_arm

# %%
import os
os.chdir('/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/9no_arm')

# %%
for f in os.listdir():
  texto, extension= os.path.splitext(f)
  #print(texto)
  print(texto.split('-'))
  d1,m1,a1,d2,m2,a2=texto.split('-')
  #print(d1)
  nuevo_archivo=f"{m1}-{d1}-{a1}-{m2}-{d2}-{a2}{extension}"
  #print(nuevo_archivo)
  os.rename(f, nuevo_archivo)

# %%
my_list_9=[]
file_list_9= glob.glob('/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/9no_arm/*.xlsx')
#print(file_list)
path_9= '/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/9no_arm/*.xlsx'
for i in sorted(glob.glob(path_9)):
  print(i)

# %%
for i in sorted(glob.glob(path_9)):
  df_9=pd.read_excel(i)
  my_list_9.append(pd.read_excel(i))
  df_todos_9=pd.concat(my_list_9,join="inner", ignore_index=True)
  df_todos_9

# %%
df_todos_9

# %%
df_todos_9['Circuito 1'].replace(
    to_replace=['---'],
    value=0,
    inplace=True
)
#fig20=df_todos_9.plot("Date","Circuito 1")

plt.plot(df_todos_9.index, df_todos_9['Circuito 1'])

plt.title('9th armónico señal agregada')
plt.xlabel('samples')
plt.ylabel('Amplitud [A]')
plt.grid()

plt.savefig('/content/imagen/9_arm_agregada_cuel_house')

# %% [markdown]
# cosfi

# %%
import os
os.chdir('/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/cosfi')

# %%
for f in os.listdir():
  texto, extension= os.path.splitext(f)
  #print(texto)
  print(texto.split('-'))
  d1,m1,a1,d2,m2,a2=texto.split('-')
  #print(d1)
  nuevo_archivo=f"{m1}-{d1}-{a1}-{m2}-{d2}-{a2}{extension}"
  #print(nuevo_archivo)
  os.rename(f, nuevo_archivo)
# Out:
# ['27', '07', '20 ', ' 28', '07', '20']
# ['28', '07', '20 ', ' 29', '07', '20']
# ['29', '07', '20 ', ' 30', '07', '20']
# ['30', '07', '20 ', ' 31', '07', '20']
# ['31', '07', '20 ', ' 01', '08', '20']
# ['01', '08', '20 ', ' 02', '08', '20']
# ['02', '08', '20 ', ' 03', '08', '20']
# ['03', '08', '20 ', ' 04', '08', '20']
# ['04', '08', '20 ', ' 05', '08', '20']
# ['05', '08', '20 ', ' 06', '08', '20']
# ['06', '08', '20 ', ' 07', '08', '20']
# ['07', '08', '20 ', ' 08', '08', '20']
# ['08', '08', '20 ', ' 09', '08', '20']
# ['09', '08', '20 ', ' 10', '08', '20']
# ['10', '08', '20 ', ' 11', '08', '20']
# ['11', '08', '20 ', ' 12', '08', '20']
# ['12', '08', '20 ', ' 13', '08', '20']
# ['13', '08', '20 ', ' 14', '08', '20']
# ['14', '08', '20 ', ' 15', '08', '20']
# ['15', '08', '20 ', ' 16', '08', '20']
# ['16', '08', '20 ', ' 17', '08', '20']
# ['17', '08', '20 ', ' 18', '08', '20']
# ['18', '08', '20 ', ' 19', '08', '20']
# ['19', '08', '20 ', ' 20', '08', '20']
# ...

# %%
my_list_cosfi=[]
file_list_cosfi= glob.glob('/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/cosfi/*.xlsx')
#print(file_list)
path_cosfi= '/content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/cosfi/*.xlsx'
for i in sorted(glob.glob(path_cosfi)):
  print(i)
# Out:
# /content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/cosfi/07-27-20 -07- 28-20.xlsx
# /content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/cosfi/07-28-20 -07- 29-20.xlsx
# /content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/cosfi/07-29-20 -07- 30-20.xlsx
# /content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/cosfi/07-30-20 -07- 31-20.xlsx
# /content/drive/MyDrive/Doctorado CyT, Maxi/Dataset -Wbox-primer dataset/Dataset -Wbox/victoria_cuel_house/Cuel_house_agregada_27_07_to_06_09/cosfi/07-31-20 -08- 01-20.xlsx
# ...

# %%
for i in sorted(glob.glob(path_cosfi)):
  df_cosfi=pd.read_excel(i)
  my_list_cosfi.append(pd.read_excel(i))
  df_todos_cosfi=pd.concat(my_list_cosfi,join="inner", ignore_index=True)
  df_todos_cosfi
# Out:
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...

# %%
df_todos_cosfi
# Out:
#       Circuito 1 Circuito 2 Circuito 3 Total                 Date
# 0            ---        ---        ---   ---  2020-07-27 00:01:00
# 1            ---        ---        ---   ---  2020-07-27 00:02:00
# 2            ---        ---        ---   ---  2020-07-27 00:03:00
# 3            ---        ---        ---   ---  2020-07-27 00:04:00
# 4            ---        ---        ---   ---  2020-07-27 00:05:00
# ...          ...        ...        ...   ...                  ...
# 60475          1          1          1     1  2020-09-06 23:56:00
# 60476          1          1          1     1  2020-09-06 23:57:00
# 60477          1          1          1     1  2020-09-06 23:58:00
# 60478          1          1          1     1  2020-09-06 23:59:00
# 60479          1          1          1     1  2020-09-07 00:00:00
#
# [60480 rows x 5 columns]

# %%
df_todos_cosfi['Circuito 1'].replace(
    to_replace=['---'],
    value=0,
    inplace=True
)
#fig22=df_todos_cosfi.plot("Date","Circuito 1")


plt.plot(df_todos_cosfi.index, np.abs( df_todos_cosfi['Circuito 1']))

plt.title('$cos\phi$ señal agregada')
plt.xlabel('samples')
plt.ylabel('$cos \phi$')
plt.grid()

plt.savefig('/content/image/cosfi')
